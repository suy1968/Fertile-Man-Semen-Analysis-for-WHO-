# %% [markdown]
# # About DataSet
#
# This dataset contains the semen parameters of a fertile man, who have achieved a pregnancy in ≤ 12 months of trying to conceive, with an abstinence period of 2-7 days, at time of semen analysis. The parameters of a semen analysis included are; Semen Volume (ml), Sperm concentration(10x6 per ml), Total sperm number (10x6 per ejaculate), Total motility (PR + NP, %), Progressive motility (PR, %), Non-progressive motility (NP, %), Immotile spermatozoa (IM, %), Vitality (%) and Normal forms (%). The dataset has been derived from the subjects used to formulate the normal semen parameters of a fertile man, stated within The WHO laboratory manual for the examination and processing of human semen, Fifth Edition and from a systematic review of published papers from 01/01/2010 to 30/04/2020, which included semen parameters of fertile men, which were conducted according to standards set within The WHO laboratory manual for the examination and processing of human semen

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'C:\Users\HP\Downloads\Fertile_Man_2020.csv')
df.head()
# Out:
#            PI Semen Volume (ml) Sperm Concentration (106/ml)  \
# 0  Aboutorabi               3.2                         27.0
# 1  Aboutorabi               0.8                        136.0
# 2  Aboutorabi               2.0                         71.0
# 3  Aboutorabi               1.0                         35.0
# 4  Aboutorabi               2.0                         46.0
#
#   Total Number (106) Total Motility (%) Progressive Motility (%)  \
# 0               86.4                 35                       20
# 1              108.8                 47                       35
# 2              142.0                 49                       42
# 3               35.0                 50                       28
# 4               92.0                 51                       28
#
#   Non-progressive Motility (%) Immotile Spermatozoa (%) Vitality (%)  \
# 0                           15                       65    NO RESULT
# ...

# %%
df.tail()
# Out:
#         PI Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 3584  Tang               1.7                         23.0               39.1
# 3585  Tang               2.5                        110.0              275.0
# 3586  Tang               2.0                        109.0              218.0
# 3587  Tang               6.2                         96.0              595.2
# 3588  Tang               3.0                         36.0              108.0
#
#      Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# 3584                 53                       52                            1
# 3585                 66                       66                            0
# 3586                 64                       44                           20
# 3587                 39                       29                           10
# 3588                 54                       38                           16
#
# ...

# %%
df.sample(6)
# Out:
#          PI Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 1864   Swan               1.9                         20.0               37.4
# 1932   Swan               6.7                         21.1              140.9
# 2700   Tang               4.0                         37.0              148.0
# 2280  Zedan               2.5                         46.0              115.0
# 2692   Tang               2.9                         28.0               81.2
# 2565   Tang               3.0                         25.0               75.0
#
#      Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# 1864                 58                       54                            4
# 1932                 60                       53                            7
# 2700                 54                       53                            1
# 2280                 65                       50                           15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PI                            3589 non-null   object
#  1   Semen Volume (ml)             3589 non-null   object
#  2   Sperm Concentration (106/ml)  3589 non-null   object
#  3   Total Number (106)            3589 non-null   object
#  4   Total Motility (%)            3589 non-null   object
#  5   Progressive Motility (%)      3589 non-null   object
#  6   Non-progressive Motility (%)  3589 non-null   object
#  7   Immotile Spermatozoa (%)      3589 non-null   object
#  8   Vitality (%)                  3589 non-null   object
#  9   Normal Forms (%)              3589 non-null   object
# dtypes: object(10)
# memory usage: 280.5+ KB

# %%
df.describe()
# Out:
#           PI Semen Volume (ml) Sperm Concentration (106/ml)  \
# count   3589              3589                         3589
# unique    10                97                          644
# top     Tang               3.0                         25.0
# freq    1200               311                           68
#
#        Total Number (106) Total Motility (%) Progressive Motility (%)  \
# count                3589               3589                     3589
# unique               1652                 88                       91
# top                  90.0                 60                NO RESULT
# freq                   39                163                      200
#
#        Non-progressive Motility (%) Immotile Spermatozoa (%) Vitality (%)  \
# count                          3589                     3589         3589
# unique                           52                       85           66
# top                               5                NO RESULT    NO RESULT
# ...

# %%
df.shape
# Out:
# (3589, 10)

# %%
df.columns
# Out:
# Index(['PI', 'Semen Volume (ml)', 'Sperm Concentration (106/ml)',
#        'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
#        'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
#        'Vitality (%)', 'Normal Forms (%)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PI                              object
# Semen Volume (ml)               object
# Sperm Concentration (106/ml)    object
# Total Number (106)              object
# Total Motility (%)              object
# Progressive Motility (%)        object
# Non-progressive Motility (%)    object
# Immotile Spermatozoa (%)        object
# Vitality (%)                    object
# Normal Forms (%)                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PI                              0
# Semen Volume (ml)               0
# Sperm Concentration (106/ml)    0
# Total Number (106)              0
# Total Motility (%)              0
# Progressive Motility (%)        0
# Non-progressive Motility (%)    0
# Immotile Spermatozoa (%)        0
# Vitality (%)                    0
# Normal Forms (%)                0
# dtype: int64

# %%
df['PI'].unique()
# Out:
# array(['Aboutorabi', 'Auger', 'Baker', 'Evgeni', 'Haugen', 'Jensen',
#        'Lotti', 'Swan', 'Zedan', 'Tang'], dtype=object)

# %%
df['PI'].value_counts()
# Out:
# Tang          1200
# Auger          826
# Swan           487
# Zedan          240
# Baker          206
# Jensen         199
# Aboutorabi     168
# Lotti          105
# Haugen          82
# Evgeni          76
# Name: PI, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('PI', data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
data_new = df[['Semen Volume (ml)', 'Sperm Concentration (106/ml)',
'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
'Vitality (%)', 'Normal Forms (%)']]

# %%
data_new = data_new.replace({'Semen Volume (ml)': {'NO RESULT': 0}})
data_new = data_new.replace({'Sperm Concentration (106/ml)': {'NO RESULT': 0}})
data_new = data_new.replace({'Total Number (106)': {'NO RESULT': 0}})
data_new = data_new.replace({'Total Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Progressive Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Non-progressive Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Immotile Spermatozoa (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Normal Forms (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Vitality (%)': {'NO RESULT': 0}})

# %%
data_new
# Out:
#      Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 0                  3.2                         27.0               86.4
# 1                  0.8                        136.0              108.8
# 2                  2.0                         71.0              142.0
# 3                  1.0                         35.0               35.0
# 4                  2.0                         46.0               92.0
# ...                ...                          ...                ...
# 3584               1.7                         23.0               39.1
# 3585               2.5                        110.0              275.0
# 3586               2.0                        109.0              218.0
# 3587               6.2                         96.0              595.2
# 3588               3.0                         36.0              108.0
#
#      Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# ...

# %%
for i in data_new.columns:
    data_new[i] = data_new[i].astype(float)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3589 entries, 0 to 3588
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Semen Volume (ml)             3589 non-null   float64
#  1   Sperm Concentration (106/ml)  3589 non-null   float64
#  2   Total Number (106)            3589 non-null   float64
#  3   Total Motility (%)            3589 non-null   float64
#  4   Progressive Motility (%)      3589 non-null   float64
#  5   Non-progressive Motility (%)  3589 non-null   float64
#  6   Immotile Spermatozoa (%)      3589 non-null   float64
#  7   Vitality (%)                  3589 non-null   float64
#  8   Normal Forms (%)              3589 non-null   float64
# dtypes: float64(9)
# memory usage: 252.5 KB

# %%
for i in data_new.columns:
    plt.figure(figsize=(15,6))
    sns.distplot(data_new[i])
    plt.xticks(rotation = 90)
    plt.show()

# %%
for i in data_new.columns:
    plt.figure(figsize=(15,6))
    sns.boxplot(data_new[i])
    plt.xticks(rotation = 90)
    plt.show()

# %%
for i in data_new.columns:
    plt.figure(figsize=(15,6))
    sns.violinplot(data_new[i])
    plt.xticks(rotation = 90)
    plt.show()

# %%
corrmat = data_new.corr()
corrmat
# Out:
#                               Semen Volume (ml)  Sperm Concentration (106/ml)  \
# Semen Volume (ml)                      1.000000                     -0.121870
# Sperm Concentration (106/ml)          -0.121870                      1.000000
# Total Number (106)                     0.399897                      0.766797
# Total Motility (%)                     0.001102                      0.079625
# Progressive Motility (%)               0.087323                      0.087168
# Non-progressive Motility (%)          -0.157477                     -0.014214
# Immotile Spermatozoa (%)               0.091834                      0.041243
# Vitality (%)                          -0.155714                     -0.182657
# Normal Forms (%)                       0.005856                      0.115217
#
#                               Total Number (106)  Total Motility (%)  \
# Semen Volume (ml)                       0.399897            0.001102
# ...

# %%
cmap = sns.diverging_palette(260,-10,s=50, l=75, n=6,
as_cmap=True)
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)
plt.show()

# %% [markdown]
# # THANK YOU
